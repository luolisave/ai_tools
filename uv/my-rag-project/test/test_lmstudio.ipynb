# %% [markdown]
# # Test
# My Random code test

# %% [markdown]
# ### LM Studio API

# %% [markdown]
# LM Studio embedding model

# %%
import lmstudio as lms
model = lms.embedding_model("nomic-ai/nomic-embed-text-v1.5")
embedding = model.embed("Your query here")
print(embedding)          # → [0.12, 0.34, …] (a NumPy array of floats)
# Out:
# [0.041335538029670715, 0.015028790570795536, -0.1476372331380844, -0.007339674048125744, 0.07081074267625809, -0.013792542740702629, 0.044592469930648804, -0.017444303259253502, 0.001351019600406289, -0.03948036581277847, 0.012880277819931507, 0.04525366425514221, 0.029096849262714386, -0.0404081717133522, -0.047990165650844574, -0.08031998574733734, 0.026134178042411804, -0.06949060410261154, 0.06094596907496452, 0.05536665767431259, -0.06950127333402634, -0.041642069816589355, -0.06497219949960709, -0.00294399238191545, 0.16492417454719543, -0.025215642526745796, -0.0017623341409489512, 0.01917722448706627, -0.04508424922823906, 0.0021177183371037245, 0.007170555647462606, 0.023817740380764008, 0.006716687697917223, 0.00805757101625204, -0.036448992788791656, 0.007144631817936897, 0.0046333931386470795, 0.009415315464138985, 0.016013989225029945, 0.013217649422585964, 0.07116784155368805, -0.0279842596501112, 0.0034792907536029816, -0.07152100652456284, 0.028460990637540817, -0.003
# ...
